# %% [markdown]
# <div style='text-align:left;width:40%;float:left;'>
#     <a href="./MLP.ipynb">Anterior</a>
# </div>
# <div style='text-align:right;width:30%; float:right'>
#     <a href="./SVM.ipynb">Próximo</a>
# </div>
